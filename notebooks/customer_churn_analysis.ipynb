# %% [markdown]
# # Customer Churn Prediction\nProjeto de Data Science com dados sintéticos para previsão de churn.

# %%
import pandas as pd\ndf = pd.read_csv('../dados/clientes_churn.csv')\ndf.head()

# %%
df.info()\ndf['churn'].value_counts(normalize=True)

# %%
df.groupby('tipo_contrato')['churn'].mean().sort_values(ascending=False)

# %% [markdown]
# ## Próximos passos\nExecute `python/treinar_modelos.py` para comparar Regressão Logística e Random Forest.
